# %% [markdown]
# # Analysis of current Counter Cleaner Errors

# %% [markdown]
# ## Infos
# - [GFD-1961](https://green-fusion.atlassian.net/browse/GFD-1961)
# - [error filter in der datenbank](https://green-fusion.atlassian.net/browse/GFD-753)
# - [Counter Cleaner](https://www.notion.so/green-fusion/Counter-Cleaner-47de96e809a24a27b6682550a53c6652)

# %%
#imports
import pandas as pd
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt

# %%
# functions
## Function to show both % and count
def make_autopct(values):
    def autopct(pct):
        count = int(round(pct / 100. * sum(values)))
        return f'{pct:.1f}%\n({count})'
    return autopct

# %% [markdown]
# ## Get data

# %%
# Load CSV file into DataFrame
#df = pd.read_csv("_WITH_LatestCreated_AS_SELECT_dccm_sensor_id_MAX_dccm_created_at_202505221126.csv")
df = pd.read_csv("df_latest_errors2025-07-07.csv")

# %%
# Show the first 10 rows
if True:
    display(df.head(10))
# Out:
#        id  sensor_id             reference_date unit  \
# 0  163437          4  2025-06-30 23:59:59+00:00  kWh
# 1  163438          8  2025-06-30 23:59:59+00:00  kWh
# 2  142109         20  2024-02-29 23:59:59+00:00  kWh
# 3  142133         21  2024-02-29 23:59:59+00:00  kWh
# 4  163441         24  2025-06-30 23:59:59+00:00  kWh
# 5  163444         35  2025-06-30 23:59:59+00:00   °C
# 6  142218         41  2023-03-31 23:59:59+00:00   m³
# 7  142242         47  2023-03-31 23:59:59+00:00  kWh
# 8  160278         66  2025-04-30 23:59:59+00:00   m³
# 9  160281         73  2025-04-30 23:59:59+00:00  kWh
#
#                              error  hydraulic_location_index      source  \
# 0        No values greater than 0.                       1.0  GETEC_MQTT
# 1               No complete data.                        1.0  GETEC_MQTT
# 2               No complete data.                        1.0  GETEC_MQTT
# 3               No complete data.                        1.0  GETEC_MQTT
# 4                   Data is empty.                       1.0  GETEC_MQTT
# 5  No values after removing drops.                       1.0  GETEC_MQTT
# 6               No complete data.                        1.0  GETEC_MQTT
# 7               No complete data.                        1.0  GETEC_MQTT
# 8               No complete data.                        1.0  GETEC_MQTT
# 9               No complete data.                        2.0  GETEC_MQTT
#
#    building_id  gf_standard_id      acronym
# 0          111             2.0  e_chp(n)_hm
# 1          195             6.0   e_hw(n)_hm
# 2          113             4.0       e_g_hm
# 3          113             6.0   e_hw(n)_hm
# 4          114             5.0   e_hc(n)_hm
# 5          101             NaN          NaN
# 6          118           133.0       v_g_gm
# 7          118             5.0   e_hc(n)_hm
# 8          160           133.0       v_g_gm
# 9          146             5.0   e_hc(n)_hm

# %%
##Show the Last 10 rows
if True:
   display(df.tail(10))
# Out:
#          id  sensor_id             reference_date unit  \
# 439  163367      33632  2025-05-31 23:59:59+00:00  kWh
# 440  163368      33634  2025-05-31 23:59:59+00:00  kWh
# 441  163369      33636  2025-05-31 23:59:59+00:00  kWh
# 442  163370      33638  2025-05-31 23:59:59+00:00  kWh
# 443  163371      33640  2025-05-31 23:59:59+00:00  kWh
# 444  163315      34151  2025-05-31 23:59:59+00:00  kWh
# 445  163321      34446  2025-05-31 23:59:59+00:00  kWh
# 446  163322      34451  2025-05-31 23:59:59+00:00  kWh
# 447  163330      34835  2025-05-31 23:59:59+00:00  kWh
# 448  163333      34992  2025-05-31 23:59:59+00:00  kWh
#
#                          error  hydraulic_location_index         source  \
# 439  No values greater than 0.                       2.0  GREENBOX_MQTT
# 440         No complete data.                        1.0  GREENBOX_MQTT
# 441  No values greater than 0.                       2.0  GREENBOX_MQTT
# 442         No complete data.                        1.0  GREENBOX_MQTT
# 443  No values greater than 0.                       2.0  GREENBOX_MQTT
# 444         No complete data.                        2.0  GREENBOX_MQTT
# 445  No values greater than 0.                       1.0  GREENBOX_MQTT
# 446         No complete data.                        1.0  GREENBOX_MQTT
# 447         No complete data.                        1.0  GREENBOX_MQTT
# 448         No complete data.                        1.0  GREENBOX_MQTT
#
#      building_id  gf_standard_id                  acronym
# 439         1799             NaN                      NaN
# 440         1799             NaN                      NaN
# 441         1799             NaN                      NaN
# 442         1799             NaN                      NaN
# 443         1799             NaN                      NaN
# 444         1850           400.0  eel_hp(n)_em_supply_act
# 445         1698           465.0           e_lh(n)_hmsubs
# 446         1850           400.0  eel_hp(n)_em_supply_act
# 447         2001           400.0  eel_hp(n)_em_supply_act
# 448         2002           400.0  eel_hp(n)_em_supply_act

# %%
# basic data analysis from the strings 
df.describe(include=['object'])
# Out:
#                    reference_date unit               error      source  \
# count                         449  448                 449         449
# unique                         26    3                   6           5
# top     2025-06-30 23:59:59+00:00  kWh  No complete data.   GETEC_MQTT
# freq                          266  306                 216         219
#
#            acronym
# count          402
# unique          15
# top     e_hc(n)_hm
# freq            85

# %% [markdown]
# ## Datetime consideration

# %%
# string to datetime
#df['created_at'] = pd.to_datetime(df['created_at'])
df['reference_date'] = pd.to_datetime(df['reference_date'])

# %%
#dates consideration
if False:
    # Earliest (oldest) timestamp
    earliest = df['created_at'].min()
    
    # Latest (most recent) timestamp
    latest = df['created_at'].max()
    print("created_at")
    print("Earliest timestamp:", earliest)
    print("Latest timestamp:", latest)
    print(20*"--")
    # Earliest (oldest) timestamp
    earliest = df['reference_date'].min()
    
    # Latest (most recent) timestamp
    latest = df['reference_date'].max()
    print("reference_date")
    print("Earliest timestamp:", earliest)
    print("Latest timestamp:", latest)

# %% [markdown]
# ## Error Type

# %%
#type of error
error_counts=df['error'].dropna().value_counts()
error_counts
# Out:
# error
# No complete data.                                                          216
# Data is empty.                                                             131
# No values greater than 0.                                                   68
# Series cannot be transformed to be monotonic increasing. Deleting data.     23
# No values after removing drops.                                             10
# Less than 24 hours of data.                                                  1
# Name: count, dtype: int64

# %%
# Plot pie chart
       
if True:   
    # Create pie chart
    fig, ax = plt.subplots(figsize=(8, 8))
    
    # Plot pie without labels
    wedges, texts, autotexts = ax.pie(
        error_counts,
        labels=None,
        autopct=make_autopct(error_counts),
        startangle=140,
        textprops={'fontsize': 10}
    )
    
    # Add vertical legend outside
    ax.legend(
        wedges,
        error_counts.index,
        title="Error Types",
        loc="center left",
        bbox_to_anchor=(1, 0.5),
        fontsize=10
    )
    
    ax.set_title("Error Distribution", fontsize=14)
    #plt.tight_layout()
    plt.show()
    # export
    #plt.savefig("pics/error_Distribution_chart.jpg")

# %%
# pic 5 occurence of each errors
sampled_list = []

for meter_type_val, group_df in df.groupby('error'):
    sample_size = min(5, len(group_df))
    sampled = group_df.sample(n=sample_size, replace=False)
    sampled_list.append(sampled)

df_sampled = pd.concat(sampled_list).reset_index(drop=True)

#sort
df_sampled_sorted = df_sampled.sort_values(by='error').reset_index(drop=True)
df_sampled_sorted[["building_id","acronym","error","sensor_id"]]
# Out:
#     building_id      acronym  \
# 0           427   e_hw(n)_hm
# 1           364   e_hc(n)_hm
# 2           210   e_hc(n)_hm
# 3           364       v_g_gm
# 4           745       v_g_gm
# 5           598    v_b(n)_gm
# 6           118       v_g_gm
# 7           154   e_hw(n)_hm
# 8           597      e_dh_hm
# 9          1860  v_chp(n)_gm
# 10          111  v_chp(n)_gm
# 11          135   e_hc(n)_hm
# 12          101          NaN
# 13          148   e_hc(n)_hm
# 14          147       e_g_hm
# 15          111          NaN
# 16         1826       v_g_gm
# 17          472    v_b(n)_gm
# 18          111   e_hc(n)_hm
# 19         1729    v_b(n)_gm
# 20         1361   e_hc(n)_hm
# 21          392          NaN
# 22         1413      e_dh_hm
# 23         1360   e_hc(n)_hm
# 24          304       v_g_gm
# 25         1360    e_b(n)_hm
#
#                                                 error  sensor_id
# 0                                      Data is empty.      13024
# 1                                      Data is empty.       7771
# 2                                      Data is empty.       1225
# 3                                      Data is empty.       7770
# 4                                      Data is empty.      13590
# 5                         Less than 24 hours of data.      29808
# 6                                  No complete data.          41
# 7                                  No complete data.          88
# 8                                  No complete data.       22808
# 9                                  No complete data.       26011
# 10                                 No complete data.         785
# 11                    No values after removing drops.        844
# 12                    No values after removing drops.         35
# 13                    No values after removing drops.        216
# 14                    No values after removing drops.        258
# 15                    No values after removing drops.        506
# 16                          No values greater than 0.      31755
# 17                          No values greater than 0.       8916
# 18                          No values greater than 0.        117
# 19                          No values greater than 0.      25331
# 20                          No values greater than 0.      23481
# 21  Series cannot be transformed to be monotonic i...       7131
# 22  Series cannot be transformed to be monotonic i...      15804
# 23  Series cannot be transformed to be monotonic i...      23416
# 24  Series cannot be transformed to be monotonic i...       4911
# 25  Series cannot be transformed to be monotonic i...      23426

# %% [markdown]
# ## acronym

# %%
#type of acronym
acronym_counts=df['acronym'].dropna().value_counts()
acronym_counts
# Out:
# acronym
# e_hc(n)_hm                     85
# v_g_gm                         78
# e_hw(n)_hm                     73
# e_g_hm                         64
# v_b(n)_gm                      49
# e_b(n)_hm                      14
# eel_hp(n)_em_supply_act        11
# e_dh_hm                         9
# e_chp(n)_hm                     6
# v_chp(n)_gm                     6
# e_g_hmalt                       2
# e_hc(n)_hmalt                   2
# eel_chp(n)_em_discharge_act     1
# eel_chp(n)_em_supply_act        1
# e_lh(n)_hmsubs                  1
# Name: count, dtype: int64

# %%
# Plot pie chart
if True:
    # Create pie chart
    fig, ax = plt.subplots(figsize=(8, 8))
    
    # Plot pie without labels
    wedges, texts, autotexts = ax.pie(
        acronym_counts,
        labels=None,
        autopct=make_autopct(acronym_counts),
        startangle=140,
        textprops={'fontsize': 10}
    )
    
    # Add vertical legend outside
    ax.legend(
        wedges,
        acronym_counts.index,
        title="Acronyms",
        loc="center left",
        bbox_to_anchor=(1, 0.5),
        fontsize=10
    )
    
    ax.set_title("Acronyms Distribution", fontsize=14)
    #plt.tight_layout()
    plt.show()# Or use plt.savefig("error_pie_chart.pdf")
    # export
    #plt.savefig("pics/Acronyms_Distribution_chart.jpg")

# %%
# pic 2 occurence of each errors
sampled_list = []

for meter_type_val, group_df in df.groupby('acronym'):
    sample_size = min(2, len(group_df))
    sampled = group_df.sample(n=sample_size, replace=False)
    sampled_list.append(sampled)

df_sampled = pd.concat(sampled_list).reset_index(drop=True)

#sort
df_sampled_sorted = df_sampled.sort_values(by='acronym').reset_index(drop=True)
df_sampled_sorted[["building_id","acronym","error","sensor_id"]]
# Out:
#     building_id                      acronym                      error  \
# 0           386                    e_b(n)_hm         No complete data.
# 1           379                    e_b(n)_hm         No complete data.
# 2           111                  e_chp(n)_hm  No values greater than 0.
# 3          1360                  e_chp(n)_hm  No values greater than 0.
# 4           766                      e_dh_hm  No values greater than 0.
# 5          1739                      e_dh_hm         No complete data.
# 6           232                       e_g_hm         No complete data.
# 7           250                       e_g_hm             Data is empty.
# 8          2224                    e_g_hmalt             Data is empty.
# 9           414                    e_g_hmalt         No complete data.
# 10          129                   e_hc(n)_hm             Data is empty.
# 11          120                   e_hc(n)_hm             Data is empty.
# 12          754                e_hc(n)_hmalt         No complete data.
# 13          754                e_hc(n)_hmalt         No complete data.
# 14          162                   e_hw(n)_hm         No complete data.
# 15          109                   e_hw(n)_hm         No complete data.
# 16         1698               e_lh(n)_hmsubs  No values greater than 0.
# 17         1874  eel_chp(n)_em_discharge_act             Data is empty.
# 18         1874     eel_chp(n)_em_supply_act             Data is empty.
# 19         2001      eel_hp(n)_em_supply_act         No complete data.
# 20         2002      eel_hp(n)_em_supply_act         No complete data.
# 21          468                    v_b(n)_gm  No values greater than 0.
# 22         1512                    v_b(n)_gm         No complete data.
# 23         1860                  v_chp(n)_gm         No complete data.
# 24          754                  v_chp(n)_gm         No complete data.
# 25          115                       v_g_gm             Data is empty.
# 26          294                       v_g_gm         No complete data.
#
#     sensor_id
# 0        5634
# 1        5591
# 2           4
# 3       23441
# 4       10128
# 5       28354
# 6         344
# 7        3387
# 8        7026
# 9        7051
# 10        990
# 11        239
# 12       9478
# 13       9477
# 14       2209
# 15       1908
# 16      34446
# 17       3998
# 18       3997
# 19      34835
# 20      34992
# 21       8901
# 22      22297
# 23      26011
# 24       9487
# 25        225
# 26        699

# %% [markdown]
# ## group acronym in meter types

# %%
#filter to obtain the metertype
def get_meter_type(acronym):
    if isinstance(acronym, str):
        if '_hm' in acronym:
            return 'heat_meter'
        elif '_gm' in acronym:
            return 'gas_meter'
        elif '_em' in acronym:
            return 'electricity_meter'
    return 'other'

df['meter_type'] = df['acronym_n'].apply(get_meter_type)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'acronym_n'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 12
#       9             return 'electricity_meter'
#      10     return 'other'
# ---> 12 df['meter_type'] = df['acronym_n'].apply(get_meter_type)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'acronym_n'

# %%
meter_type=df['meter_type'].dropna().value_counts()
meter_type
# Out:
# meter_type
# heat_meter           140
# gas_meter             43
# other                 12
# electricity_meter      4
# Name: count, dtype: int64

# %%
#display others
if False:
    df.loc[df['meter_type'] == 'other']

# %%
# Plot pie chart
if True:
    # Create pie chart
    fig, ax = plt.subplots(figsize=(8, 8))
    
    # Plot pie without labels
    wedges, texts, autotexts = ax.pie(
        meter_type,
        labels=None,
        autopct=make_autopct(meter_type),
        startangle=140,
        textprops={'fontsize': 10}
    )
    
    # Add vertical legend outside
    ax.legend(
        wedges,
        meter_type.index,
        title="meter_type",
        loc="center left",
        bbox_to_anchor=(1, 0.5),
        fontsize=10
    )
    
    ax.set_title("Meter type Distribution", fontsize=14)
    #plt.tight_layout()
    plt.show()# Or use plt.savefig("error_pie_chart.pdf")
    # export
    #plt.savefig("pics/Acronyms_Distribution_chart.jpg")

# %%
# pic 5 occurence of meter type
sampled_list = []

for meter_type_val, group_df in df.groupby('meter_type'):
    sample_size = min(5, len(group_df))
    sampled = group_df.sample(n=sample_size, replace=False)
    sampled_list.append(sampled)

df_sampled = pd.concat(sampled_list).reset_index(drop=True)
#sort
df_sampled_sorted = df_sampled.sort_values(by='meter_type').reset_index(drop=True)
df_sampled_sorted[["building","meter_type","error","sensor_id"]]
# Out:
#     building         meter_type  \
# 0        536  electricity_meter
# 1        537  electricity_meter
# 2       1404  electricity_meter
# 3        546  electricity_meter
# 4        472          gas_meter
# 5        269          gas_meter
# 6        467          gas_meter
# 7        406          gas_meter
# 8          5          gas_meter
# 9        144         heat_meter
# 10       147         heat_meter
# 11       179         heat_meter
# 12       127         heat_meter
# 13       206         heat_meter
# 14       325              other
# 15       111              other
# 16       142              other
# 17       325              other
# 18       325              other
#
#                                                 error  sensor_id
# 0                                      Data is empty.      15673
# 1   Series cannot be transformed to be monotonic i...      16868
# 2                                  No complete data.       20825
# 3                                  No complete data.       13867
# 4                           No values greater than 0.       8916
# 5                                      Data is empty.        550
# 6                           No values greater than 0.      23053
# 7                                  No complete data.        6934
# 8                           No values greater than 0.       3459
# 9                           No values greater than 0.       1647
# 10                          No values greater than 0.        318
# 11                                     Data is empty.       3413
# 12                                     Data is empty.        903
# 13                                     Data is empty.        282
# 14                          No values greater than 0.       7773
# 15                    No values after removing drops.        506
# 16                          No values greater than 0.       1011
# 17                          No values greater than 0.       7780
# 18                          No values greater than 0.       7779

# %% [markdown]
# ## group by
# - error : 'No values greater than 0', 'Data is empty'
# - Meter type : 'gas_meter', 'heat_meter'

# %%
# filter by error type
filtered_df = df.loc[(df['error'] == 'Data is empty.') | (df['error'] == 'No values greater than 0.')]
# filter meter_type
filtered_df = filtered_df.loc[(df['meter_type'] == 'gas_meter') | (filtered_df['meter_type'] == 'heat_meter')]
# group by keep 5 random entries
group_cols = ['error', 'meter_type']
sampled_list = []

for group_vals, indices in filtered_df.groupby(group_cols).groups.items():
    group_df = filtered_df.loc[indices]
    sample_size = min(5, len(group_df))
    sampled = group_df.sample(n=sample_size, replace=False)
    sampled_list.append(sampled)

df_sampled = pd.concat(sampled_list).reset_index(drop=True)
#sort result
df_sampled_sorted = df_sampled.sort_values(by=['error','meter_type']).reset_index(drop=True)
#display the necessary
df_sampled_sorted#[["building","meter_type","error","sensor_id"]]
# Out:
#     sensor_id  building                                            address  \
# 0         394       129                                      Grünrockweg 8
# 1         981       120                                       Büchsenweg 9
# 2        7163       375                                       Lindenstr. 8
# 3        1779       209                                  Breitkopfstr. 107
# 4         708       201                                  Breitkopfstr. 121
# 5        7673       416                                   Haslocher Weg 75
# 6        3396       247                               Alexandrinenstr. 100
# 7        1640       115                                      Klemkestr. 20
# 8        3405       247                               Alexandrinenstr. 100
# 9         621       116                                  Breitkopfstr. 103
# 10       8904       466                                  Rodewaldstraße 19
# 11        670       141                                  Aalesunder Str. 9
# 12      27175      1501                                  Vastersstr. 23+25
# 13       5877       396                             Reginhardstraße 16, HZ
# 14       8916       472           Gottfried-Benn-Weg 50 (/Else-Ury-Weg 51)
# 15      23436      1360    Kirschanger 4, Schwielowsee - Technikzentrale 1
# 16       1647       144                                     Neumarkplan 9C
# 17      23481      1361  Kirschanger 2, Schwielowsee - Unterstation Hau...
# 18      23406      1360    Kirschanger 4, Schwielowsee - Technikzentrale 1
# 19        353       136                                     Lincolnstr. 60
#
#     gfstandard_id    acronym_n                      error  \
# 0           133.0       v_g_gm             Data is empty.
# 1           133.0       v_g_gm             Data is empty.
# 2           133.0       v_g_gm             Data is empty.
# 3           133.0       v_g_gm             Data is empty.
# 4           133.0       v_g_gm             Data is empty.
# 5             4.0       e_g_hm             Data is empty.
# 6             5.0   e_hc(n)_hm             Data is empty.
# 7             6.0   e_hw(n)_hm             Data is empty.
# 8             4.0       e_g_hm             Data is empty.
# 9             5.0   e_hc(n)_hm             Data is empty.
# 10          128.0    v_b(n)_gm  No values greater than 0.
# 11          133.0       v_g_gm  No values greater than 0.
# 12          128.0    v_b(n)_gm  No values greater than 0.
# 13          130.0  v_chp(n)_gm  No values greater than 0.
# 14          128.0    v_b(n)_gm  No values greater than 0.
# 15            2.0  e_chp(n)_hm  No values greater than 0.
# 16            6.0   e_hw(n)_hm  No values greater than 0.
# 17            5.0   e_hc(n)_hm  No values greater than 0.
# 18            5.0   e_hc(n)_hm  No values greater than 0.
# 19            6.0   e_hw(n)_hm  No values greater than 0.
#
#                          created_at      reference_date  meter_type
# 0  2025-05-02 20:01:49.738000+02:00 2025-03-31 23:59:59   gas_meter
# 1  2025-05-02 21:34:55.832000+02:00 2025-03-31 23:59:59   gas_meter
# 2  2025-05-03 05:16:13.378000+02:00 2025-03-31 23:59:59   gas_meter
# 3  2025-05-02 23:54:26.859000+02:00 2025-03-31 23:59:59   gas_meter
# 4  2025-05-02 21:07:59.388000+02:00 2025-03-31 23:59:59   gas_meter
# 5  2025-05-03 05:19:18.913000+02:00 2025-03-31 23:59:59  heat_meter
# 6  2025-05-03 01:17:11.890000+02:00 2025-03-31 23:59:59  heat_meter
# 7  2025-05-02 23:18:18.834000+02:00 2025-03-31 23:59:59  heat_meter
# 8  2025-05-03 01:18:11.937000+02:00 2025-03-31 23:59:59  heat_meter
# 9  2025-05-02 20:47:22.174000+02:00 2025-03-31 23:59:59  heat_meter
# 10 2025-05-03 06:00:56.720000+02:00 2025-03-31 23:59:59   gas_meter
# 11 2025-05-02 20:57:46.094000+02:00 2025-03-31 23:59:59   gas_meter
# 12 2025-05-03 13:55:32.659000+02:00 2025-03-31 23:59:59   gas_meter
# 13 2025-05-03 04:18:59.392000+02:00 2025-03-31 23:59:59   gas_meter
# 14 2025-05-03 06:02:17.374000+02:00 2025-03-31 23:59:59   gas_meter
# 15 2025-05-03 11:54:50.248000+02:00 2025-03-31 23:59:59  heat_meter
# 16 2025-05-02 23:21:23.571000+02:00 2025-03-31 23:59:59  heat_meter
# 17 2025-05-03 12:06:04.364000+02:00 2025-03-31 23:59:59  heat_meter
# 18 2025-05-03 11:45:37.358000+02:00 2025-03-31 23:59:59  heat_meter
# 19 2025-05-02 19:47:29.962000+02:00 2025-03-31 23:59:59  heat_meter

# %% [markdown]
# ## analysis of strange heat meter behavior

# %%
# filter by error type
filtered_df = df.loc[(df['error'] == 'No values after removing drops.') | (df['error'] == 'No complete data. ')].sort_values(by=['error']).reset_index(drop=True)
filtered_df[["building","meter_type","error","sensor_id"]].sort_values(by=['sensor_id']).reset_index(drop=True).head()#.iloc[5:]
# Out:
#    building  meter_type                            error  sensor_id
# 0       101       other  No values after removing drops.         35
# 1       141  heat_meter  No values after removing drops.        162
# 2       148  heat_meter  No values after removing drops.        216
# 3       147  heat_meter  No values after removing drops.        258
# 4       145  heat_meter               No complete data.         354

# %%
list_of_strange_heat_meter_1=[162,216,258,354,740,844,954,1685,1739] #interfereces
list_of_strange_heat_meter_2=[35,506,961,1553,13196] # rauschen
list_of_strange_heat_meter_3=[661,1632,25797] # no data since x time
list_of_strange_heat_meter_4=[1903,1910,2195,2209,13008,13014,13022,13024] # jumps / drops but count
list_of_strange_heat_meter_5=[2989,4911,20825] #  outliers but counts
list_of_strange_heat_meter_6=[6932,6934,10072] # where's the problem ?

# %% [markdown]
# ### interference

# %% [markdown]
# ![](pics/interferences.png)

# %%
df.loc[df['sensor_id'].isin(list_of_strange_heat_meter_1)]
# Out:
#      sensor_id  building                  address  gfstandard_id   acronym_n  \
# 25         740       103   Wilhelm-Guddorf-Str. 6            5.0  e_hc(n)_hm
# 26         844       135  Wilhelm-Guddorf-Str. 14            5.0  e_hc(n)_hm
# 55         954       157     Alfred-Randt-Str. 20            4.0      e_g_hm
# 59        1685       144           Neumarkplan 9C            4.0      e_g_hm
# 78        1739       136           Lincolnstr. 60            4.0      e_g_hm
# 145        162       141        Aalesunder Str. 9            4.0      e_g_hm
# 154        216       148       Erich-Kurz-Str. 13            5.0  e_hc(n)_hm
# 160        258       147        Pistoriusplatz 15            4.0      e_g_hm
# 174        354       145             Götelstr. 99            4.0      e_g_hm
#
#                                error                       created_at  \
# 25   No values after removing drops. 2025-05-02 21:14:12.954000+02:00
# 26   No values after removing drops. 2025-05-02 21:20:22.836000+02:00
# 55   No values after removing drops. 2025-05-02 21:28:35.259000+02:00
# 59   No values after removing drops. 2025-05-02 23:32:46.966000+02:00
# 78   No values after removing drops. 2025-05-02 23:46:12.798000+02:00
# 145  No values after removing drops. 2025-05-02 18:40:35.711000+02:00
# 154  No values after removing drops. 2025-05-02 18:59:16.659000+02:00
# 160  No values after removing drops. 2025-05-02 19:15:37.118000+02:00
# 174               No complete data.  2025-05-02 19:48:32.922000+02:00
#
#          reference_date  meter_type
# 25  2025-03-31 23:59:59  heat_meter
# 26  2025-03-31 23:59:59  heat_meter
# 55  2025-03-31 23:59:59  heat_meter
# 59  2025-03-31 23:59:59  heat_meter
# 78  2025-03-31 23:59:59  heat_meter
# 145 2025-03-31 23:59:59  heat_meter
# 154 2025-03-31 23:59:59  heat_meter
# 160 2025-03-31 23:59:59  heat_meter
# 174 2025-03-31 23:59:59  heat_meter

# %% [markdown]
# ### rauschen

# %% [markdown]
# ![](pics/rauschen.png)

# %%
df.loc[df['sensor_id'].isin(list_of_strange_heat_meter_2)]
# Out:
#      sensor_id  building                                       address  \
# 3          506       111                                 Weverstr. 11A
# 34        1553       101                                Lincolnstr. 16
# 71         961       142                               Neumarkplan 10A
# 85          35       101                                Lincolnstr. 16
# 146      13196       600  Eintrachtstr. 1 (versorgt Eintrachtstr. 1+3)
#
#      gfstandard_id acronym_n                            error  \
# 3              NaN       NaN  No values after removing drops.
# 34             NaN       NaN  No values after removing drops.
# 71             NaN       NaN  No values after removing drops.
# 85             NaN       NaN  No values after removing drops.
# 146            3.0   e_dh_hm               No complete data.
#
#                           created_at      reference_date  meter_type
# 3   2025-05-02 20:23:38.329000+02:00 2025-03-31 23:59:59       other
# 34  2025-05-02 23:03:40.138000+02:00 2025-03-31 23:59:59       other
# 71  2025-05-02 21:29:50.062000+02:00 2025-03-31 23:59:59       other
# 85  2025-05-02 18:06:27.001000+02:00 2025-03-31 23:59:59       other
# 146 2025-05-03 07:46:11.272000+02:00 2025-03-31 23:59:59  heat_meter

# %% [markdown]
# ### no data since x time

# %% [markdown]
# ![](pics/nodatasincextime.png)

# %%
df.loc[df['sensor_id'].isin(list_of_strange_heat_meter_3)]
# Out:
#      sensor_id  building           address  gfstandard_id   acronym_n  \
# 6          661       198  Residenzstr. 147          133.0      v_g_gm
# 74        1632       198  Residenzstr. 147            6.0  e_hw(n)_hm
# 189      25797      1864      Lommenweg 10          128.0   v_b(n)_gm
#
#                   error                       created_at      reference_date  \
# 6    No complete data.  2025-05-02 20:55:41.295000+02:00 2025-03-31 23:59:59
# 74   No complete data.  2025-05-02 23:16:15.781000+02:00 2025-03-31 23:59:59
# 189  No complete data.  2025-05-03 13:05:17.325000+02:00 2025-03-31 23:59:59
#
#      meter_type
# 6     gas_meter
# 74   heat_meter
# 189   gas_meter

# %% [markdown]
# ### jump / drop and count

# %% [markdown]
# ![](pics/jumpdrops.png)

# %%
df.loc[df['sensor_id'].isin(list_of_strange_heat_meter_4)]
# Out:
#      sensor_id  building                address  gfstandard_id   acronym_n  \
# 66        2195       162      Jerichower Str. 4            5.0  e_hc(n)_hm
# 81        1903       137     Stendaler Str. 142            6.0  e_hw(n)_hm
# 82        1910       137     Stendaler Str. 142            5.0  e_hc(n)_hm
# 91        2209       162      Jerichower Str. 4            6.0  e_hw(n)_hm
# 136      13008       388       Jägerstraße 7-13            6.0  e_hw(n)_hm
# 137      13014       388       Jägerstraße 7-13          133.0      v_g_gm
# 139      13022       427  Baadenberger Str. 140          133.0      v_g_gm
# 141      13024       427  Baadenberger Str. 140            6.0  e_hw(n)_hm
#
#                   error                       created_at      reference_date  \
# 66   No complete data.  2025-05-03 00:25:23.787000+02:00 2025-03-31 23:59:59
# 81   No complete data.  2025-05-03 00:16:35.343000+02:00 2025-03-31 23:59:59
# 82   No complete data.  2025-05-03 00:20:47.184000+02:00 2025-03-31 23:59:59
# 91   No complete data.  2025-05-03 00:33:16.013000+02:00 2025-03-31 23:59:59
# 136  No complete data.  2025-05-03 07:32:37.372000+02:00 2025-03-31 23:59:59
# 137  No complete data.  2025-05-03 07:33:38.542000+02:00 2025-03-31 23:59:59
# 139  No complete data.  2025-05-03 07:34:54.875000+02:00 2025-03-31 23:59:59
# 141  No complete data.  2025-05-03 07:35:58.488000+02:00 2025-03-31 23:59:59
#
#      meter_type
# 66   heat_meter
# 81   heat_meter
# 82   heat_meter
# 91   heat_meter
# 136  heat_meter
# 137   gas_meter
# 139   gas_meter
# 141  heat_meter

# %% [markdown]
# ### outliers but counts

# %% [markdown]
# ![](pics/outliers.png)

# %%
df.loc[df['sensor_id'].isin(list_of_strange_heat_meter_5)]
# Out:
#      sensor_id  building                       address  gfstandard_id  \
# 99        2989       304          Buchholzer Strasse 4            4.0
# 105       4911       304          Buchholzer Strasse 4          133.0
# 197      20825      1404  Halle, Bielefelder Straße 26          400.0
#
#                    acronym_n               error  \
# 99                    e_g_hm  No complete data.
# 105                   v_g_gm  No complete data.
# 197  eel_hp(n)_em_supply_act  No complete data.
#
#                           created_at      reference_date         meter_type
# 99  2025-05-03 01:10:56.124000+02:00 2025-03-31 23:59:59         heat_meter
# 105 2025-05-03 02:42:53.339000+02:00 2025-03-31 23:59:59          gas_meter
# 197 2025-05-03 10:01:39.753000+02:00 2025-03-31 23:59:59  electricity_meter

# %% [markdown]
# ## Case data stops to flow

# %%
filtered_df = df.loc[(df['error'] == 'Data is empty.')].sort_values(by=['meter_type']).reset_index(drop=True)
list(filtered_df.sort_values(by=['address']).reset_index(drop=True)["sensor_id"].iloc[25:30])
# Out:
# [361, 708, 1292, 1325, 904]

# %%
list_of_meter_data_that_stoped_flowing=set([361,424,394,387,323,661,1632,25797,1606,1574,1698,550,1537,621,102,13590,1731, 703, 1779, 1805, 1056,361, 708, 1292, 1325, 904]) 
list_of_meter_data_schow_nothing_in_2_years=set([3417, 3396, 3405, 87, 672, 2886, 1722, 152, 24]) 
df.loc[df['sensor_id'].isin(list_of_meter_data_that_stoped_flowing)].reset_index(drop=True)#[["building","meter_type","error","acronym_n","sensor_id"]]
# Out:
#     sensor_id  building                address  gfstandard_id   acronym_n  \
# 0         661       198       Residenzstr. 147          133.0      v_g_gm
# 1        1292       201      Breitkopfstr. 121            6.0  e_hw(n)_hm
# 2         550       269      Breitkopfstr. 105          133.0      v_g_gm
# 3        1056       270      Breitkopfstr. 109            5.0  e_hc(n)_hm
# 4        1537       116      Breitkopfstr. 103            6.0  e_hw(n)_hm
# 5         621       116      Breitkopfstr. 103            5.0  e_hc(n)_hm
# 6         703       209      Breitkopfstr. 107            5.0  e_hc(n)_hm
# 7         904       119      Breitkopfstr. 130            5.0  e_hc(n)_hm
# 8        1325       201      Breitkopfstr. 121            5.0  e_hc(n)_hm
# 9        1574       249      Blumberger Damm 6            4.0      e_g_hm
# 10       1698       182      Breitkopfstr. 101            6.0  e_hw(n)_hm
# 11       1779       209      Breitkopfstr. 107          133.0      v_g_gm
# 12        708       201      Breitkopfstr. 121          133.0      v_g_gm
# 13       1606       258       An der Kappe 56D            4.0      e_g_hm
# 14       1632       198       Residenzstr. 147            6.0  e_hw(n)_hm
# 15       1805       209      Breitkopfstr. 107            6.0  e_hw(n)_hm
# 16       1731       269      Breitkopfstr. 105            5.0  e_hc(n)_hm
# 17        102       269      Breitkopfstr. 105            6.0  e_hw(n)_hm
# 18      13590       745      Borussiastraße 50          133.0      v_g_gm
# 19        323       182      Breitkopfstr. 101            5.0  e_hc(n)_hm
# 20        361       220      Breitkopfstr. 119            5.0  e_hc(n)_hm
# 21        387       180  Stolzenhagener Str. 7            4.0      e_g_hm
# 22        394       129          Grünrockweg 8          133.0      v_g_gm
# 23        424       169        Poelchaustr. 32            6.0  e_hw(n)_hm
# 24      25797      1864           Lommenweg 10          128.0   v_b(n)_gm
#
#                  error                       created_at      reference_date  \
# 0   No complete data.  2025-05-02 20:55:41.295000+02:00 2025-03-31 23:59:59
# 1       Data is empty. 2025-05-02 22:23:11.638000+02:00 2025-03-31 23:59:59
# 2       Data is empty. 2025-05-02 20:31:44.682000+02:00 2025-03-31 23:59:59
# 3       Data is empty. 2025-05-02 21:45:21.136000+02:00 2025-03-31 23:59:59
# 4       Data is empty. 2025-05-02 23:02:28.035000+02:00 2025-03-31 23:59:59
# 5       Data is empty. 2025-05-02 20:47:22.174000+02:00 2025-03-31 23:59:59
# 6       Data is empty. 2025-05-02 21:06:59.343000+02:00 2025-03-31 23:59:59
# 7       Data is empty. 2025-05-02 21:25:31.052000+02:00 2025-03-31 23:59:59
# 8       Data is empty. 2025-05-02 22:30:22.937000+02:00 2025-03-31 23:59:59
# 9       Data is empty. 2025-05-02 23:07:46.944000+02:00 2025-03-31 23:59:59
# 10      Data is empty. 2025-05-02 23:36:55.622000+02:00 2025-03-31 23:59:59
# 11      Data is empty. 2025-05-02 23:54:26.859000+02:00 2025-03-31 23:59:59
# 12      Data is empty. 2025-05-02 21:07:59.388000+02:00 2025-03-31 23:59:59
# 13      Data is empty. 2025-05-02 23:11:58.795000+02:00 2025-03-31 23:59:59
# 14  No complete data.  2025-05-02 23:16:15.781000+02:00 2025-03-31 23:59:59
# 15      Data is empty. 2025-05-03 00:02:05.602000+02:00 2025-03-31 23:59:59
# 16      Data is empty. 2025-05-02 23:43:04.336000+02:00 2025-03-31 23:59:59
# 17      Data is empty. 2025-05-02 18:24:09.931000+02:00 2025-03-31 23:59:59
# 18      Data is empty. 2025-05-03 07:51:56.513000+02:00 2025-03-31 23:59:59
# 19      Data is empty. 2025-05-02 19:37:11.757000+02:00 2025-03-31 23:59:59
# 20      Data is empty. 2025-05-02 19:51:35.416000+02:00 2025-03-31 23:59:59
# 21      Data is empty. 2025-05-02 19:58:46.175000+02:00 2025-03-31 23:59:59
# 22      Data is empty. 2025-05-02 20:01:49.738000+02:00 2025-03-31 23:59:59
# 23      Data is empty. 2025-05-02 20:07:58.170000+02:00 2025-03-31 23:59:59
# 24  No complete data.  2025-05-03 13:05:17.325000+02:00 2025-03-31 23:59:59
#
#     meter_type
# 0    gas_meter
# 1   heat_meter
# 2    gas_meter
# 3   heat_meter
# 4   heat_meter
# 5   heat_meter
# 6   heat_meter
# 7   heat_meter
# 8   heat_meter
# 9   heat_meter
# 10  heat_meter
# 11   gas_meter
# 12   gas_meter
# 13  heat_meter
# 14  heat_meter
# 15  heat_meter
# 16  heat_meter
# 17  heat_meter
# 18   gas_meter
# 19  heat_meter
# 20  heat_meter
# 21  heat_meter
# 22   gas_meter
# 23  heat_meter
# 24   gas_meter

# %% [markdown]
# ticket that explains some of the data:
# - [GETEC buildings DOWN](https://green-fusion.atlassian.net/browse/GF-9851)
